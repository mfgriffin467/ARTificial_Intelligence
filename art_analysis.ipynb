# %% [markdown]
# # Import libraries and files

# %%
import numpy as np
import pandas as pd
import os 
import shutil 
import time
import re

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 1000)

# %%
art = pd.read_csv("all_data_info.csv")

# %% [markdown]
# ## Specific checks

# %%
# Specific lookup

art[art.new_filename == '2965.jpg']
# Out:
#                artist date      genre  pixelsx  pixelsy  size_bytes   source          style       title    artist_group  in_train new_filename  date_mod  century  max_century
# 74474  Stefan Luchian  NaN  landscape    592.0    476.0     71887.0  wikiart  Impressionism  After Rain  train_and_test     False     2965.jpg      -100        0           20

# %%
art[art['artist'] == 'Paul Cezanne'][art['in_train'] == False]
# Out:
# C:\Users\Mike\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#              artist    date              genre  pixelsx  pixelsy  size_bytes   source               style                                              title    artist_group  in_train new_filename  date_mod  century  max_century
# 30593  Paul Cezanne    1878     genre painting   3176.0   2618.0   1139110.0  wikiart  Post-Impressionism                                       Four Bathers  train_and_test     False    19446.jpg      1878       19           20
# 30594  Paul Cezanne    1894         still life   3176.0   2606.0    737724.0  wikiart  Post-Impressionism                             Curtain, Jug and Fruit  train_and_test     False    94593.jpg      1894       19           20
# 30598  Paul Cezanne    1877  symbolic painting   3176.0   2600.0    958500.0  wikiart       Impressionism                                  The Eternal Woman  train_and_test     False    64480.jpg      1877       19           20
# 30608  Paul Cezanne  c.1905          landscape   3176.0   2552.0    836544.0  wikiart              Cubism     Montagne Sainte-Victoire and the Black Chateau  train_and_test     False    71902.jpg      1905       20           20
# 30609  Paul Cezanne  c.1890          landscape   3176.0   2551.0    811453.0  wikiart  Post-Impressionism                               Mont Sainte-Victoire  train_and_test     False    11113.jpg      1890       19           20
# 30612  Paul Cezanne  c.1875     genre painting   3176.0   2540.0    884549.0  wikiart       Impressionism                               Afternoon in Naples   train_and_test     False     7959.jpg      1875       19           20
# 30621  Paul Cezanne    1865         still life   3176.0   2497.0    582879.0  wikiart         Romanticism                     Still Life with Bread and Eggs  train_and_test     False    71756.jpg      1865       19           20
# 30623  Paul Cezanne    1890          landscape   3176.0   2473.0    920524.0  wikiart  Post-Impressionism                                House with Red Roof  train_and_test     False    34815.jpg      1890       19           20
# 30630  Paul Cezanne  c.1866           portrait   2536.0   3061.0    856153.0  wikiart         Romanticism              Portrait of Uncle Dominique as a Monk  train_and_test     False    64759.jpg      1866       19           20
# 30636  Paul Cezanne  c.1895      self-portrait   2536.0   3001.0   1097996.0  wikiart  Post-Impressionism                                      Self-Portrait  train_and_test     False    22331.jpg      1895       19           20
# 30645  Paul Cezanne  c.1890          landscape   3200.0   2136.0    776685.0  wikiart  Post-Impressionism                               Mont Sainte-Victoire  train_and_test     False      116.jpg      1890       19           20
# 30652  Paul Cezanne    1894         still life   3200.0   1833.0    597454.0  wikiart  Post-Impressionism               Still life, jug and fruit on a table  train_and_test     False    68019.jpg      1894       19           20
# 30653  Paul Cezanne    1894         still life   2024.0   2842.0    536813.0  wikiart  Post-Impressionism                      Still Life, Tulips and apples  train_and_test     False    85894.jpg      1894       19           20
# 30656  Paul Cezanne    1887     genre painting   2024.0   2692.0    512722.0  wikiart  Post-Impressionism                                             Bather  train_and_test     False    62630.jpg      1887       19           20
# 30775  Paul Cezanne  c.1870           portrait   1464.0   1177.0    350219.0  wikiart         Romanticism  Paul Alexis  Reading a Manuscript to Emile Zola    train_and_test     False    57209.jpg      1870       19           20
# 30779  Paul Cezanne    1890           portrait   1000.0   1588.0    170963.0  wikiart  Post-Impressionism                                 Boy in a Red Vest   train_and_test     False    84200.jpg      1890       19           20
# 30783  Paul Cezanne  c.1882          landscape   1280.0   1024.0    271422.0  wikiart  Post-Impressionism                                 Rocks at L'Estaque  train_and_test     False    39970.jpg      1882       19           20
# 30784  Paul Cezanne    1872          cityscape   1280.0   1024.0    285683.0  wikiart       Impressionism   The Halle aux Vins, seen from the rue de Jussieu  train_and_test     False    23887.jpg      1872       19           20
# 30792  Paul Cezanne    1906          landscape   1280.0   1020.0    223770.0  wikiart              Cubism                           The Garden at Les Lauves  train_and_test     False    17814.jpg      1906       20           20
# 30799  Paul Cezanne    1902           portrait   1024.0   1268.0    236343.0  wikiart  Post-Impressionism                               Child in a Straw Hat  train_and_test     False    73285.jpg      1902       20           20
# 30800  Paul Cezanne  c.1894          landscape   1280.0   1014.0    299243.0  wikiart  Post-Impressionism                 Millstone and Cistern Under Trees   train_and_test     False     7450.jpg      1894       19           20
# 30820  Paul Cezanne    1867          cityscape   1280.0   1004.0    340567.0  wikiart         Romanticism                         Rue des Saules. Montmartre  train_and_test     False    37503.jpg      1867       19           20
# 30840  Paul Cezanne  c.1904          landscape   1280.0    992.0    355898.0  wikiart              Cubism                                     Chateau Noir    train_and_test     False    12387.jpg      1904       20           20
# 30845  Paul Cezanne  c.1878          landscape   1232.0   1024.0    264568.0  wikiart       Impressionism                         The Pool at Jas de Bouffan  train_and_test     False     5182.jpg      1878       19           20
# 30848  Paul Cezanne    1900         still life   1256.0   1004.0    121350.0  wikiart  Post-Impressionism                            Still Life with Oranges  train_and_test     False    76200.jpg      1900       20           20
# 30849  Paul Cezanne    1877         still life   1231.0   1024.0    375812.0  wikiart       Impressionism                    Compotier and Plate of Biscuits  train_and_test     False     4346.jpg      1877       19           20
# 30851  Paul Cezanne    1879          landscape   1230.0   1024.0    318814.0  wikiart       Impressionism                  L'Estaque. View through the Trees  train_and_test     False    74272.jpg      1879       19           20
# 30854  Paul Cezanne    1879          landscape   1024.0   1226.0    308936.0  wikiart       Impressionism                 Path at the Entrance to the Forest  train_and_test     False    90887.jpg      1879       19           20
# 30864  Paul Cezanne  c.1878     genre painting   1216.0   1024.0    324078.0  wikiart       Impressionism                                    Legendary Scene  train_and_test     False     8145.jpg      1878       19           20
# 30870  Paul Cezanne  c.1905          landscape   1206.0   1024.0    256119.0  wikiart              Cubism                                       Chateau Noir  train_and_test     False    21879.jpg      1905       20           20
# 30871  Paul Cezanne  c.1875     genre painting   1280.0    963.0    308045.0  wikiart       Impressionism                                 Life in the Fields  train_and_test     False    83257.jpg      1875       19           20
# 30874  Paul Cezanne  c.1906          landscape   1195.0   1024.0    367416.0  wikiart              Cubism          Mont Sainte-Victoire Seen from les Lauves  train_and_test     False    82003.jpg      1906       20           20
# 30885  Paul Cezanne  c.1879          landscape    940.0   1280.0    328131.0  wikiart  Post-Impressionism                               Bottom of the Ravine  train_and_test     False     1191.jpg      1879       19           20
# 31001  Paul Cezanne    1866           portrait    871.0   1019.0    157147.0  wikiart         Romanticism                            Portrait of a Young Man  train_and_test     False    70338.jpg      1866       19           20
# 31004  Paul Cezanne    1867           portrait    823.0   1074.0    163715.0  wikiart         Romanticism                                             Sorrow  train_and_test     False    89097.jpg      1867       19           20
# 31011  Paul Cezanne  c.1902          landscape    827.0   1052.0    204709.0  wikiart              Cubism                               Mont Sainte-Victoire  train_and_test     False    85875.jpg      1902       20           20
# 31017  Paul Cezanne    1881          landscape    831.0   1039.0   1215652.0  wikiart  Post-Impressionism                             Houses in the Greenery  train_and_test     False    18867.jpg      1881       19           20
# 31021  Paul Cezanne    1878           portrait    870.0    987.0    209366.0  wikiart       Impressionism                       Portrait of the Artist's Son  train_and_test     False     2149.jpg      1878       19           20
# 31027  Paul Cezanne    1898          cityscape    833.0   1019.0    213523.0  wikiart              Cubism                                Farm at Montgeroult  train_and_test     False    35112.jpg      1898       19           20
# 31029  Paul Cezanne    1897          landscape    776.0   1092.0    236486.0  wikiart              Cubism                              Bibemus. The Red Rock  train_and_test     False    27733.jpg      1897       19           20
# 31035  Paul Cezanne    1873         still life   1131.0    746.0    212441.0  wikiart         Romanticism                      Still Life Apples and a Glass  train_and_test     False    37947.jpg      1873       19           20
# 31048  Paul Cezanne    1906          landscape    806.0   1032.0    209785.0  wikiart              Cubism                                Bend in Forest Road  train_and_test     False    27042.jpg      1906       20           20
# 31052  Paul Cezanne    1866     genre painting   1025.0    796.0    173398.0  wikiart         Romanticism                                          Promenade  train_and_test     False    55696.jpg      1866       19           20
# 31059  Paul Cezanne    1867     genre painting    763.0   1047.0    203838.0  wikiart         Romanticism                                          The Feast  train_and_test     False    88589.jpg      1867       19           20
# 31062  Paul Cezanne  c.1888    flower painting    768.0   1033.0    614207.0  wikiart  Post-Impressionism                                          Rose Bush  train_and_test     False    35784.jpg      1888       19           20
# 31065  Paul Cezanne    1906           portrait    796.0    973.0    190743.0  wikiart              Cubism                                   The Old Gardener  train_and_test     False    59417.jpg      1906       20           20
# 31066  Paul Cezanne  c.1877    flower painting    798.0    970.0    219727.0  wikiart       Impressionism                               Two Vases of Flowers  train_and_test     False   103113.jpg      1877       19           20
# 31068  Paul Cezanne  c.1873           portrait    787.0    981.0    232047.0  wikiart       Impressionism                                               Girl  train_and_test     False    76017.jpg      1873       19           20

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Analysis over time

# %%
def extract_year(x):
    try:
        return int(re.search(r'\d+', str(x)).group(0))
    except:
        return -100

art['date_mod'] = art.date.apply(lambda x: extract_year(x))
art['century'] = art.date_mod.apply(lambda x: x//100 + 1)
art[['century','in_train']].groupby(['century']).count()
# Out:
#          in_train
# century
# 0           26366
# 2               1
# 10              2
# 11              5
# 12             49
# 13             36
# 14            255
# 15           1989
# 16           3093
# 17           3494
# 18           3192
# 19          23560
# 20          40637
# 21            571

# %%
# Manual fix

max_century = art[['artist','century']].groupby(['artist']).max().reset_index()
max_century.columns = ['artist', 'max_century']
art = art.merge(max_century, on = 'artist')
art.head()
art[['max_century','in_train']].groupby(['max_century']).count()
# Out:
#              in_train
# max_century
# 0                1667
# 11                  7
# 12                 42
# 13                 56
# 14                327
# 15               1874
# 16               4532
# 17               4505
# 18               3288
# 19              18130
# 20              64351
# 21               4471

# %%
art[['max_century','in_train']].groupby(['max_century']).sum()
# Out:
#              in_train
# max_century
# 0              1293.0
# 11                7.0
# 12               34.0
# 13               41.0
# 14              246.0
# 15             1390.0
# 16             3574.0
# 17             3416.0
# 18             2511.0
# 19            13934.0
# 20            49557.0
# 21             3430.0

# %%
art[art.max_century > 18][['artist','in_train']].groupby(['artist']).count().sort_values(by='in_train', ascending= False).head(150).sum()
# Out:
# in_train    42640
# dtype: int64

# %%
# Check gaps

art[art.max_century == 0][['artist','in_train']].groupby(['artist']).count().sort_values(by='in_train', ascending= False).head(150)
# Out:
#                                                     in_train
# artist
# Antoine Blanchard                                        178
# Maurice Utrillo                                          148
# John Miller                                               80
# Edmund Dulac                                              68
# William Orpen                                             68
# Charles Tunnicliffe                                       60
# Adam Baltatu                                              60
# John Austen                                               57
# Mustafa Duzgunman                                         50
# Jacob van Strij                                           42
# Basuki Abdullah                                           41
#  Fyodor Solntsev                                          37
# Herrad of Landsberg                                       36
# Vladimir Dimitrov                                         33
# Fikret Mualla Saygi                                       29
# garrett ames ledbetter                                    28
# Hakuin Ekaku                                              26
# andrea loney                                              23
# Giovanni Battista Torriglia                               22
# R. B. Kitaj                                               22
# Sengai                                                    20
# han van meegeren                                          20
# Sheikh Hamdullah                                          18
# Fornasetti                                                18
# Bui Xuan Phai                                             18
# Abdullah Suriosubroto                                     17
# Church of the Covenant (Boston)                           16
# Zenkei Shibayama                                          16
# Goldstein Grigoriy                                        16
# Armand Henrion                                            15
# kirsty ellen mottram                                      15
# charley toorop                                            13
# Fern Coppedge                                             12
# Tosa Mitsuoki                                             12
# Juan Carlos Castagnino                                    12
# Mir Emad Hassani                                          11
# Owon                                                      10
# Ahmed Karahisari                                          10
# Mir Ali Tabrizi                                           10
# Xu Wei                                                     9
# Auguste Rodin                                              9
# Mustafa Rakim                                              9
# Maurice Sendak                                             9
# Utagawa Kunisada II                                        9
# Hatip Mehmed Efendi                                        8
# Enji Torei                                                 8
# Wu Daozi                                                   8
# Nakagawa Soen                                              7
# from Beauty and the Beast                                  6
# from The Tempest                                           6
# The Nightingale                                            5
# Soen Kogaku                                                5
# lisa rasmussen                                             5
# from the Picture Book for the Red Cross                    5
# ∞ / unknown detail of detail                               5
# illustration to Fairies I Have Met                         5
# Wang Wei                                                   5
# Hadis-i Şerîf                                              4
# Hadis-i Şerîfler                                           2
# The Hen                                                    1
# ∞ / détail 4875812                                         1
# The appearance of a-Fukagawa-Nakamichi-Geisha-o...         1
# The appearance of a waitress at Fukagawa in the...         1
# The Yellow River Breaches its Course                       1
# The Waving Surface of the Autumn Flood                     1
# The cat witch                                              1
# ∞ / détail 4894231                                         1
# The foxes have holes                                       1
# The Singer Fate Fashioned to Her Liking                    1
# The Prince Asked Who She Was                               1
# trois sorcières courent sur la lande                      1
# waiting for the deputation of boyars                       1
# costume for Ida Rubinstein as Helene                       1
# The Emperor Shah Jahan                                     1
# The Eagles                                                 1
# The Couture                                                1
# The mortally wounded Taira Tomomori with ahuge ...         1
# ∞ / détail 4914800                                         1
# The Appearance of an Urban Widow of the Kansei era         1
# The Appearance of a concubine of the Bunka Era             1
# The Appearance of a Young Lady from Nagoya Duri...         1
# The Appearance of a Town Geisha, a Bargirl in t...         1
# The Appearance of a Kyoto Waitress in the Meiji...         1
# The Appearance of a Kept Woman of the Kaei Era             1
# ∞ / détail 511130-512739                                   1
# The Appearance of a Brothel Geisha of the Koka Era         1
# Ten Thousand Riplets on the Yangzi                         1
# Tejo e topo do arco da Rua Augusta                         1
# trois sorcières assises sur la lande                      1
# Tu t'en iras les pieds devant                              1
# the Old Fish Market                                        1
# les sorcières dansant autour                              1
# les trois sorcières agenouillées                         1
# les trois sorcières                                       1
# White Frost, Sunrise                                       1
# les trois socières font la ronde                          1
# Spring                                                     1
# les sorcières-1                                           1
# Yosemite Valley                                            1
# the Creator, the days of creation                          1
# les sorcières                                             1
# Young Greeks at the Mosque                                 1
# grand chat                                                 1
# entrée des sorcières                                     1
# assassinat de Banquo                                       1
# champ à Slack                                              1
# Waking up                                                  1
# no. 209                                                    1
# Waking Up 2                                                1
# Vue prise du Mamelon vert                                  1
# Vue de la route du col d'Aspin                             1
# no. 817B                                                   1
# Vitoria                                                    1
# nude and with pitcher                                      1
# original drawing                                           1
# Und Die Kraft Und Die Herrlichkeit                         1
# portrait composition                                       1
# said Joe                                                   1
# said Scrooge, caustic and cold as ever                     1
# Two Nazi Soldiers Mistreating Jews 1942                    1
# detail                                                     1
# said one                                                   1
# The scorpion                                               1
# St. Ives                                                   1
# Piute Indian at Bridal Veil Falls, Yosemite                1
# Sow a reasonable, good, eternal …                          1
# Consciousness                                              1
# Benjamin and Flopsy Bunny                                  1
# Beyit                                                      1
# Bow                                                        1
# Camel driver                                               1
# Cat On A Cushion                                           1
# Ceifeiras                                                  1
# Church of the Covenant (Boston)                            1
# Clouds Rising from the Green Sea                           1
# Consider the lilies                                        1
# Fatiha Sûresi ve Bakara Sûresi'nin ilk 4 âyeti             1
# Contemplation                                              1
# Cornwall                                                   1
# Death in the Desert                                        1
# Driven by the Spirit                                       1
# Driven by the spirit                                       1
# Dua                                                        1
# During Death Oblivion                                      1
# Early Summer's Rain                                        1
# Beauty                                                     1
# Battle of the Somme                                        1
# Bakara Sûresi'nin ilk 4 âyeti                              1
# Baffin Bay                                                 1
# 2. Stanley Hawk                                            1

# %% [markdown]
# ## Summaries

# %%
summary = art[['artist','style','pixelsx']].groupby(['style','artist']).count()#.sort_values(by='pixelsx', ascending=False).head(100)
summary.reset_index(inplace=True)
#summary.nlargest(5,columns = 'pixelsx')
#summary.sort_values(by='pixelsx', ascending=False)

# %%
# Top 50 artists
art[['artist','in_train']].groupby(['artist']).count().sort_values(by='in_train', ascending=False).head(10)
# Out:
#                             in_train
# artist
# John Singer Sargent              500
# Rembrandt                        500
# Pablo Picasso                    500
# Ivan Shishkin                    500
# Ivan Aivazovsky                  500
# Giovanni Battista Piranesi       500
# Gustave Dore                     500
# Pierre-Auguste Renoir            500
# Ilya Repin                       500
# Marc Chagall                     500

# %%
art[['genre','in_train']].groupby(['genre']).count().sort_values(by='in_train', ascending=False).head(10)
# Out:
#                     in_train
# genre
# portrait               16847
# landscape              15006
# genre painting         14260
# abstract                9498
# religious painting      7429
# cityscape               5348
# sketch and study        3644
# illustration            3202
# still life              3132
# symbolic painting       2545

# %%
art[['style','in_train']].groupby(['style']).count().sort_values(by='in_train', ascending=False).head(10)
# Out:
#                       in_train
# style
# Impressionism            10643
# Realism                  10523
# Romanticism               9285
# Expressionism             7013
# Post-Impressionism        5778
# Art Nouveau (Modern)      4899
# Baroque                   4400
# Surrealism                4167
# Symbolism                 3476
# Rococo                    2733

# %% [markdown]
# ### Filter for image upload

# %%
### Filter for at least 100 images

#art['category_combination'] = art['genre'] + "_" + art['style'] + "_" + art['artist']
#filt = art[art['in_train'] == True] 
#filt = filt[['category_combination','in_train']].groupby(['category_combination']).count().sort_values(by = 'in_train', ascending= False).head(100).reset_index()
#top_combs = filt.category_combination.to_list()
#df_filt = art[art['in_train'] == True][art['category_combination'].isin(top_combs)]
#df_filt.head()

# %%
### Filter for sample of top 100 19th century plus artists


# Filter top artists
print(art.shape)
art_filt = art[art.max_century > 18][art.in_train == True]
print(art_filt.shape)
top_100 = art_filt[['artist', 'in_train']].groupby(['artist']).count().sort_values(by = 'in_train', ascending = False).head(100).reset_index().artist.to_list()
art_filt = art_filt[art_filt['artist'].isin(top_100)]
print(art_filt.shape)

# Filter top genres
top_15 = art_filt[['genre', 'in_train']].groupby(['genre']).count().sort_values(by = 'in_train', ascending = False).head(15).reset_index().genre.to_list()
art_filt = art_filt[art_filt['genre'].isin(top_15)]
print(art_filt.shape)

# Filter top styles
top_15 = art_filt[['style', 'in_train']].groupby(['style']).count().sort_values(by = 'in_train', ascending = False).head(15).reset_index()['style'].to_list()
art_filt = art_filt[art_filt['style'].isin(top_15)]
print(art_filt.shape)

# Manual drop of artists after other filters applied
remove_list = ['Albert Bierstadt','George Romney']
art_filt = art_filt[~art_filt.artist.isin(remove_list)]
print(art_filt.shape)


#art_filt = df_filt1.sample(frac=0.5)
#art_filt.shape
# Out:
# (103250, 15)
# (66921, 15)
# (26326, 15)
# (24305, 15)
# (21792, 15)
# (21763, 15)
# C:\Users\Mike\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
train_df = art_filt[['new_filename','genre','style','artist']]
train_df.shape
# Out:
# (21763, 4)

# %%
train_df.groupby(['genre']).count().sort_values(by='style', ascending=False)
# Out:
#                     new_filename  style  artist
# genre
# landscape                   4847   4847    4847
# portrait                    4405   4405    4405
# genre painting              3620   3620    3620
# cityscape                   1467   1467    1467
# sketch and study            1212   1212    1212
# illustration                1005   1005    1005
# symbolic painting            960    960     960
# design                       834    834     834
# still life                   737    737     737
# nude painting (nu)           614    614     614
# religious painting           592    592     592
# flower painting              544    544     544
# marina                       509    509     509
# self-portrait                318    318     318
# abstract                      99     99      99

# %%
#train_df = art[art.genre == 'still life'][art.in_train == True]
#train_df = train_df[['new_filename','artist','style']]
#train_df.dropna(axis=0, inplace=True)
#print(train_df.shape)
train_df.to_csv("train_df.csv", index=False)
train_df.head()
# Out:
#     new_filename   genre        style           artist
# 364    99442.jpg  marina  Romanticism  Ivan Aivazovsky
# 365    81750.jpg  marina  Romanticism  Ivan Aivazovsky
# 366    82140.jpg  marina  Romanticism  Ivan Aivazovsky
# 367    74871.jpg  marina  Romanticism  Ivan Aivazovsky
# 369     7390.jpg  marina  Romanticism  Ivan Aivazovsky

# %% [markdown]
# ### Create file transfer

# %%
file_list = train_df.new_filename.to_list()

# %%
start_time = time.time()
source_path = 'C:\\Users\\Mike\\Documents\\Analytics\\Personal projects\\huge_art_collection\\train\\'
destination_path = 'C:\\Users\\Mike\\Documents\\Analytics\\Personal projects\\huge_art_collection\\copy_files\\'

for files in file_list:
    source = source_path + files
    destination = destination_path + files
    dest = shutil.copyfile(source, destination)
    
end_time = time.time()
print("time taken: ", end_time - start_time)
# Out:
# time taken:  1043.89142537117

# %%
art[art['genre'] == 'design'][art['style'] == 'Art Nouveau (Modern)']
# Out:
# C:\Users\Mike\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                     artist    date   genre  pixelsx  pixelsy  size_bytes   source                 style                                              title    artist_group  in_train new_filename  date_mod  century  max_century
# 4390                          Odilon Redon  c.1907  design    840.0   1113.0    311877.0  wikiart  Art Nouveau (Modern)                                         Decoration  train_and_test      True    11932.jpg      1907       20           20
# 4472                          Odilon Redon  c.1909  design    646.0   1008.0    172282.0  wikiart  Art Nouveau (Modern)                            Design for a Prayer Rug  train_and_test     False    53185.jpg      1909       20           20
# 5804             Henri de Toulouse-Lautrec  c.1896  design    603.0    768.0     86582.0  wikiart  Art Nouveau (Modern)                               Couverture for Elles  train_and_test      True    63838.jpg      1896       19           20
# 5836             Henri de Toulouse-Lautrec    1893  design    700.0    601.0    289688.0  wikiart  Art Nouveau (Modern)                     Coverage of the Original Print  train_and_test      True    49929.jpg      1893       19           20
# 5973                      Konstantin Somov    1907  design    761.0   1000.0    220236.0  wikiart  Art Nouveau (Modern)                            Title Page of 'Theatre'  train_and_test      True    19537.jpg      1907       20           20
# ...                                    ...     ...     ...      ...      ...         ...      ...                   ...                                                ...             ...       ...          ...       ...      ...          ...
# 101257                         Emile Galle  1900.0  design    311.0    570.0     54040.0  wikiart  Art Nouveau (Modern)                                          Fireflies  train_and_test      True    39922.jpg      1900       20           20
# 101258                         Emile Galle  1900.0  design    346.0    480.0    101305.0  wikiart  Art Nouveau (Modern)                    Vase mit Irisblüten, Frankreich  train_and_test      True    11096.jpg      1900       20           20
# 101892                              Jester    1925  design    475.0    667.0     85352.0  wikiart  Art Nouveau (Modern)  Costume designs for "Petrushka" by Stravinsky ...  train_and_test      True    74749.jpg      1925       20           20
# 102417  Nikolai Evreinov "Pro Scena Suo.."    1915  design    454.0    646.0    103982.0  wikiart  Art Nouveau (Modern)                             Draft for a book cover  train_and_test      True    99511.jpg      1915       20           20
# 103238                           Harlequin    1915  design    316.0    502.0     37466.0  wikiart  Art Nouveau (Modern)               Costume design for "Venetian madmen"  train_and_test     False     8710.jpg      1915       20           20
#
# [1054 rows x 15 columns]

# %%
art.groupby(['genre']).count()
# Out:
#                           artist   date  pixelsx  pixelsy  size_bytes  source  style  title  artist_group  in_train  new_filename  date_mod  century  max_century
# genre
# abstract                    9498   8148     9498     9498        9498    9498   9465   9498          9498      9498          9498      9498     9498         9498
# advertisement                 82     67       82       82          82      82     82     82            82        82            82        82       82           82
# allegorical painting        1034    762     1034     1034        1034    1034   1033   1034          1034      1034          1034      1034     1034         1034
